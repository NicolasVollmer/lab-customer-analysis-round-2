# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Lab | Customer Analysis Round 2
#
# For this lab, we will be using the marketing_customer_analysis.csv file that you can find in the files_for_lab folder. Check out the files_for_lab/about.md to get more information if you are using the Online Excel.
#
# Note: For the next labs we will be using the same data file. Please save the code, so that you can re-use it later in the labs following this lab.
#
# ### Dealing with the data
#
# 1. Show the dataframe shape.
# 2. Standardize header names.
# 3. Which columns are numerical?
# 4. Which columns are categorical?
# 5. Check and deal with NaN values.
# 6. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.
# 7. BONUS: Put all the previously mentioned data transformations into a function.

# %%
# loading file, showing head, tail and shape - no empty rows at the tail end as in round 1 - 10910 rows altogether

data = pd.read_csv('files_for_lab/csv_files/marketing_customer_analysis.csv')
data = data.drop(['Unnamed: 0'],axis=1)
display(data.shape)
display(data.columns)
display(data.head())
display(data.tail())
# Out:
# (10910, 25)
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size', 'Vehicle Type'],
#       dtype='object')
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/18/11         Employed      M   48029      Suburban
# 1           1/18/11       Unemployed      F       0      Suburban
# 2           2/10/11         Employed      M   22139      Suburban
# 3           1/11/11         Employed      M   49078      Suburban
# 4           1/17/11    Medical Leave      F   23675      Suburban
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# 0        Married                    61                      7.0
# 1         Single                    64                      3.0
# 2         Single                   100                     34.0
# 3         Single                    97                     10.0
# 4        Married                   117                      NaN
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                             52                        0.0
# 1                             26                        0.0
# 2                             31                        0.0
# 3                              3                        0.0
# 4                             31                        NaN
#
#    Number of Policies     Policy Type        Policy Renew Offer Type  \
# 0                   9  Corporate Auto  Corporate L3           Offer3
# 1                   1   Personal Auto   Personal L3           Offer4
# 2                   2   Personal Auto   Personal L3           Offer3
# 3                   2  Corporate Auto  Corporate L3           Offer2
# 4                   7   Personal Auto   Personal L2           Offer1
#
#   Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size Vehicle Type
# 0         Agent          292.800000  Four-Door Car      Medsize          NaN
# 1   Call Center          744.924331  Four-Door Car      Medsize          NaN
# 2   Call Center          480.000000            SUV      Medsize            A
# 3        Branch          484.013411  Four-Door Car      Medsize            A
# 4        Branch          707.925645  Four-Door Car      Medsize          NaN
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  \
# 10905  Bachelor           1/19/11       Unemployed      F       0
# 10906   College            1/6/11         Employed      F   61146
# 10907  Bachelor            2/6/11         Employed      F   39837
# 10908   College           2/13/11         Employed      F   64195
# 10909  Bachelor            1/8/11       Unemployed      M       0
#
#       Location Code Marital Status  Monthly Premium Auto  \
# 10905      Suburban        Married                   253
# 10906         Urban        Married                    65
# 10907         Rural        Married                   201
# 10908         Urban       Divorced                   158
# 10909      Suburban         Single                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 10905                      NaN                             40
# 10906                      7.0                             68
# 10907                     11.0                             63
# 10908                      0.0                             27
# 10909                     31.0                              1
#
#        Number of Open Complaints  Number of Policies     Policy Type  \
# 10905                        NaN                   7   Personal Auto
# 10906                        0.0                   6   Personal Auto
# 10907                        0.0                   2  Corporate Auto
# 10908                        4.0                   6   Personal Auto
# 10909                        0.0                   3   Personal Auto
#
#              Policy Renew Offer Type Sales Channel  Total Claim Amount  \
# 10905   Personal L1           Offer3           Web         1214.400000
# 10906   Personal L3           Offer2        Branch          273.018929
# 10907  Corporate L3           Offer1           Web          381.306996
# 10908   Personal L1           Offer1        Branch          618.288849
# 10909   Personal L1           Offer4           Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN

# %% [markdown]
# ##

# %% [markdown]
# ### Below are my functions, which I'll keep here at the top as it is the combination of my efforts further below

# %%
# I built my functions step-by-step and re-ran it multiple times to verify it was working after adding new lines

# Dataset cleaning function below

def CleanData(df):
    # below lines to change headers to lowercase
    cols = []
    for column in df.columns:
        cols.append(column.lower())
    cols
    df.columns = cols
    
    # below lines to take out spaces in titles
    df.columns = df.columns.str.replace(' ', '_')
    
    # below lines merges 3292 duplicate rows to 1516 with NaNs being replaced by valid data taken from the merged 
    # cells! See more details in my experiment section further below.
    df = df.replace('',np.nan, regex=True)
    df = df.groupby('customer',as_index=False,sort=False).last()
    duplicates1
    
    # below replaces the only 337 remaining NaNs in column 'vehicle_type' with 'unknown'
    df = df.fillna('unknown')
    
    # converting the date in column 'effective_to_date' to datetime
    df['effective_to_date'] = pd.to_datetime(df['effective_to_date'])
    
    # below lines to display result
    print("dataframe shape:", df.shape)
    print("clean headers:", df.columns)
    
    # below lines to contrast numerical and categorical data with further insight
    display(data.describe().T)
    display(data.describe(include=[object]).T)
    
    display(df.head())
    display(df.tail())

# %%
CleanData(data)
# Out:
# dataframe shape: (9134, 25)
# clean headers: Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type'],
#       dtype='object')
#                                  count          mean           std  \
# customer_lifetime_value        10910.0   8018.241094   6885.081434
# income                         10910.0  37536.284785  30359.195670
# monthly_premium_auto           10910.0     93.196059     34.442532
# months_since_last_claim        10277.0     15.149071     10.080349
# months_since_policy_inception  10910.0     48.091934     27.940675
# number_of_open_complaints      10277.0      0.384256      0.912457
# number_of_policies             10910.0      2.979193      2.399359
# total_claim_amount             10910.0    434.888330    292.180556
#
#                                        min          25%           50%  \
# customer_lifetime_value        1898.007675  4014.453113   5771.147235
# income                            0.000000     0.000000  33813.500000
# monthly_premium_auto             61.000000    68.000000     83.000000
# months_since_last_claim           0.000000     6.000000     14.000000
# months_since_policy_inception     0.000000    24.000000     48.000000
# number_of_open_complaints         0.000000     0.000000      0.000000
# number_of_policies                1.000000     1.000000      2.000000
# total_claim_amount                0.099007   271.082527    382.564630
#
#                                         75%           max
# customer_lifetime_value         8992.779137  83325.381190
# income                         62250.750000  99981.000000
# monthly_premium_auto             109.000000    298.000000
# months_since_last_claim           23.000000     35.000000
# months_since_policy_inception     71.000000     99.000000
# number_of_open_complaints          0.000000      5.000000
# number_of_policies                 4.000000      9.000000
# total_claim_amount               547.200000   2893.239678
#                    count unique            top  freq
# customer           10910   9134        ID89933     7
# state              10279      5     California  3552
# response           10279      2             No  8813
# coverage           10910      3          Basic  6660
# education          10910      5       Bachelor  3272
# effective_to_date  10910     59        1/10/11   239
# employmentstatus   10910      5       Employed  6789
# gender             10910      2              F  5573
# location_code      10910      3       Suburban  6902
# marital_status     10910      3        Married  6319
# policy_type        10910      3  Personal Auto  8128
# policy             10910      9    Personal L3  4118
# renew_offer_type   10910      4         Offer1  4483
# sales_channel      10910      4          Agent  4121
# vehicle_class      10288      6  Four-Door Car  5212
# vehicle_size       10288      3        Medsize  7251
# vehicle_type        5428      1              A  5428
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income location_code  \
# 0        2011-02-18         Employed      M   48029      Suburban
# 1        2011-01-18       Unemployed      F       0      Suburban
# 2        2011-02-10         Employed      M   22139      Suburban
# 3        2011-01-11         Employed      M   49078      Suburban
# 4        2011-01-17    Medical Leave      F   23675      Suburban
#
#   marital_status  monthly_premium_auto  months_since_last_claim  \
# 0        Married                    61                      7.0
# 1         Single                    64                      3.0
# 2         Single                   100                     34.0
# 3         Single                    97                     10.0
# 4        Married                   117                      4.0
#
#    months_since_policy_inception  number_of_open_complaints  \
# 0                             52                        0.0
# 1                             26                        0.0
# 2                             31                        0.0
# 3                              3                        0.0
# 4                             31                        0.0
#
#    number_of_policies     policy_type        policy renew_offer_type  \
# 0                   9  Corporate Auto  Corporate L3           Offer3
# 1                   1   Personal Auto   Personal L3           Offer4
# 2                   2   Personal Auto   Personal L3           Offer3
# 3                   2  Corporate Auto  Corporate L3           Offer2
# 4                   7   Personal Auto   Personal L2           Offer1
#
#   sales_channel  total_claim_amount  vehicle_class vehicle_size vehicle_type
# 0         Agent          292.800000  Four-Door Car      Medsize            A
# 1   Call Center          744.924331  Four-Door Car      Medsize      unknown
# 2   Call Center          480.000000            SUV      Medsize            A
# 3        Branch          484.013411  Four-Door Car      Medsize            A
# 4        Branch          707.925645  Four-Door Car      Medsize      unknown
#      customer       state  customer_lifetime_value response  coverage  \
# 9129  SU71163     Arizona              2771.663013       No     Basic
# 9130  QI63521      Nevada             19228.463620       No     Basic
# 9131  KX53892      Oregon              5259.444853       No     Basic
# 9132  TL39050     Arizona             23893.304100       No  Extended
# 9133  WA60547  California             11971.977650       No   Premium
#
#                  education effective_to_date employmentstatus gender  income  \
# 9129               College        2011-01-07         Employed      M   59855
# 9130  High School or Below        2011-02-24       Unemployed      M       0
# 9131               College        2011-01-06         Employed      F   61146
# 9132              Bachelor        2011-02-06         Employed      F   39837
# 9133               College        2011-02-13         Employed      F   64195
#
#      location_code marital_status  monthly_premium_auto  \
# 9129      Suburban        Married                    74
# 9130      Suburban         Single                   187
# 9131         Urban        Married                    65
# 9132         Rural        Married                   201
# 9133         Urban       Divorced                   158
#
#       months_since_last_claim  months_since_policy_inception  \
# 9129                     30.0                             82
# 9130                     14.0                             32
# 9131                      7.0                             68
# 9132                     11.0                             63
# 9133                      0.0                             27
#
#       number_of_open_complaints  number_of_policies     policy_type  \
# 9129                        4.0                   1   Personal Auto
# 9130                        0.0                   2   Personal Auto
# 9131                        0.0                   6   Personal Auto
# 9132                        0.0                   2  Corporate Auto
# 9133                        4.0                   6   Personal Auto
#
#             policy renew_offer_type sales_channel  total_claim_amount  \
# 9129   Personal L2           Offer2        Branch          355.200000
# 9130   Personal L2           Offer1        Branch          897.600000
# 9131   Personal L3           Offer2        Branch          273.018929
# 9132  Corporate L3           Offer1           Web          381.306996
# 9133   Personal L1           Offer1        Branch          618.288849
#
#       vehicle_class vehicle_size vehicle_type
# 9129   Two-Door Car      Medsize            A
# 9130     Luxury SUV      Medsize            A
# 9131  Four-Door Car      Medsize            A
# 9132     Luxury SUV      Medsize      unknown
# 9133            SUV      Medsize            A

# %% [markdown]
# #

# %%
# I established a separate function for the filtering by quarter excercise as it seemed weird to incorporate that
# into my cleaning function

# Additionally: seems weird to create a column to extract the month and use that to filter by quarter, when
# we can simply create a quarter column from our date instead and filter by that!

# def Q1Filter(df):
#     df['quarter'] = df['effective_to_date'].dt.quarter

# %%
# In the end I decided to skip this as I ran out of time...

# %%
# datacopy = data
# Q1Filter(datacopy)

# %% [markdown]
# ##

# %% [markdown]
# ### What follows below is my experimentation

# %%
# # My data cleaning requires that the headers have already been cleaned in accordance 
# # with what I set out to have them look as, so running the script below to clean the headers

# def ProperHeaders(df):
#     # below lines to change headers to lowercase
#     cols = []
#     for column in df.columns:
#         cols.append(column.lower())
#     cols
#     df.columns = cols
    
#     # below lines to take out spaces in titles
#     df.columns = df.columns.str.replace(' ', '_')

# %%
# instead of the below code I used on yesterday's excercise to only check for numerical data
# data._get_numeric_data()
# I instead use the two below to check for both numerical and categorical data with futher insights:

display(data.describe().T)
display(data.describe(include=[object]).T)
# Out:
#                                  count          mean           std  \
# Customer Lifetime Value        10910.0   8018.241094   6885.081434
# Income                         10910.0  37536.284785  30359.195670
# Monthly Premium Auto           10910.0     93.196059     34.442532
# Months Since Last Claim        10277.0     15.149071     10.080349
# Months Since Policy Inception  10910.0     48.091934     27.940675
# Number of Open Complaints      10277.0      0.384256      0.912457
# Number of Policies             10910.0      2.979193      2.399359
# Total Claim Amount             10910.0    434.888330    292.180556
#
#                                        min          25%           50%  \
# Customer Lifetime Value        1898.007675  4014.453113   5771.147235
# Income                            0.000000     0.000000  33813.500000
# Monthly Premium Auto             61.000000    68.000000     83.000000
# Months Since Last Claim           0.000000     6.000000     14.000000
# Months Since Policy Inception     0.000000    24.000000     48.000000
# Number of Open Complaints         0.000000     0.000000      0.000000
# Number of Policies                1.000000     1.000000      2.000000
# Total Claim Amount                0.099007   271.082527    382.564630
#
#                                         75%           max
# Customer Lifetime Value         8992.779137  83325.381190
# Income                         62250.750000  99981.000000
# Monthly Premium Auto             109.000000    298.000000
# Months Since Last Claim           23.000000     35.000000
# Months Since Policy Inception     71.000000     99.000000
# Number of Open Complaints          0.000000      5.000000
# Number of Policies                 4.000000      9.000000
# Total Claim Amount               547.200000   2893.239678
#                    count unique            top  freq
# Customer           10910   9134        ID89933     7
# State              10279      5     California  3552
# Response           10279      2             No  8813
# Coverage           10910      3          Basic  6660
# Education          10910      5       Bachelor  3272
# Effective To Date  10910     59        1/10/11   239
# EmploymentStatus   10910      5       Employed  6789
# Gender             10910      2              F  5573
# Location Code      10910      3       Suburban  6902
# Marital Status     10910      3        Married  6319
# Policy Type        10910      3  Personal Auto  8128
# Policy             10910      9    Personal L3  4118
# Renew Offer Type   10910      4         Offer1  4483
# Sales Channel      10910      4          Agent  4121
# Vehicle Class      10288      6  Four-Door Car  5212
# Vehicle Size       10288      3        Medsize  7251
# Vehicle Type        5428      1              A  5428

# %%
# extracting month from effective_to_date

data['effective_to_date'] = pd.to_datetime(data['effective_to_date'])
data

data['month'] = pd.DatetimeIndex(data['effective_to_date']).month
data.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income location_code  \
# 0        2011-02-18         Employed      M   48029      Suburban
# 1        2011-01-18       Unemployed      F       0      Suburban
# 2        2011-02-10         Employed      M   22139      Suburban
# 3        2011-01-11         Employed      M   49078      Suburban
# 4        2011-01-17    Medical Leave      F   23675      Suburban
#
#   marital_status  monthly_premium_auto  months_since_last_claim  \
# 0        Married                    61                      7.0
# 1         Single                    64                      3.0
# 2         Single                   100                     34.0
# 3         Single                    97                     10.0
# 4        Married                   117                      NaN
#
#    months_since_policy_inception  number_of_open_complaints  \
# 0                             52                        0.0
# 1                             26                        0.0
# 2                             31                        0.0
# 3                              3                        0.0
# 4                             31                        NaN
#
#    number_of_policies     policy_type        policy renew_offer_type  \
# 0                   9  Corporate Auto  Corporate L3           Offer3
# 1                   1   Personal Auto   Personal L3           Offer4
# 2                   2   Personal Auto   Personal L3           Offer3
# 3                   2  Corporate Auto  Corporate L3           Offer2
# 4                   7   Personal Auto   Personal L2           Offer1
#
#   sales_channel  total_claim_amount  vehicle_class vehicle_size vehicle_type  \
# 0         Agent          292.800000  Four-Door Car      Medsize          NaN
# 1   Call Center          744.924331  Four-Door Car      Medsize          NaN
# 2   Call Center          480.000000            SUV      Medsize            A
# 3        Branch          484.013411  Four-Door Car      Medsize            A
# 4        Branch          707.925645  Four-Door Car      Medsize          NaN
#
#    month
# 0      2
# 1      1
# 2      2
# 3      1
# 4      1

# %%
# df['Date'] = pd.to_datetime(df['Date']) -- if column is not datetime yet
data = data[data['effective_to_date'].dt.month <= 2]
data
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employmentstatus gender  income  \
# 0       College        2011-02-18         Employed      M   48029
# 1       College        2011-01-18       Unemployed      F       0
# 2      Bachelor        2011-02-10         Employed      M   22139
# 3       College        2011-01-11         Employed      M   49078
# 4      Bachelor        2011-01-17    Medical Leave      F   23675
# ...         ...               ...              ...    ...     ...
# 10905  Bachelor        2011-01-19       Unemployed      F       0
# 10906   College        2011-01-06         Employed      F   61146
# 10907  Bachelor        2011-02-06         Employed      F   39837
# 10908   College        2011-02-13         Employed      F   64195
# 10909  Bachelor        2011-01-08       Unemployed      M       0
#
#       location_code marital_status  monthly_premium_auto  \
# 0          Suburban        Married                    61
# 1          Suburban         Single                    64
# 2          Suburban         Single                   100
# 3          Suburban         Single                    97
# 4          Suburban        Married                   117
# ...             ...            ...                   ...
# 10905      Suburban        Married                   253
# 10906         Urban        Married                    65
# 10907         Rural        Married                   201
# 10908         Urban       Divorced                   158
# 10909      Suburban         Single                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# 2                         34.0                             31
# 3                         10.0                              3
# 4                          NaN                             31
# ...                        ...                            ...
# 10905                      NaN                             40
# 10906                      7.0                             68
# 10907                     11.0                             63
# 10908                      0.0                             27
# 10909                     31.0                              1
#
#        number_of_open_complaints  number_of_policies     policy_type  \
# 0                            0.0                   9  Corporate Auto
# 1                            0.0                   1   Personal Auto
# 2                            0.0                   2   Personal Auto
# 3                            0.0                   2  Corporate Auto
# 4                            NaN                   7   Personal Auto
# ...                          ...                 ...             ...
# 10905                        NaN                   7   Personal Auto
# 10906                        0.0                   6   Personal Auto
# 10907                        0.0                   2  Corporate Auto
# 10908                        4.0                   6   Personal Auto
# 10909                        0.0                   3   Personal Auto
#
#              policy renew_offer_type sales_channel  total_claim_amount  \
# 0      Corporate L3           Offer3         Agent          292.800000
# 1       Personal L3           Offer4   Call Center          744.924331
# 2       Personal L3           Offer3   Call Center          480.000000
# 3      Corporate L3           Offer2        Branch          484.013411
# 4       Personal L2           Offer1        Branch          707.925645
# ...             ...              ...           ...                 ...
# 10905   Personal L1           Offer3           Web         1214.400000
# 10906   Personal L3           Offer2        Branch          273.018929
# 10907  Corporate L3           Offer1           Web          381.306996
# 10908   Personal L1           Offer1        Branch          618.288849
# 10909   Personal L1           Offer4           Web         1021.719397
#
#        vehicle_class vehicle_size vehicle_type  month
# 0      Four-Door Car      Medsize          NaN      2
# 1      Four-Door Car      Medsize          NaN      1
# 2                SUV      Medsize            A      2
# 3      Four-Door Car      Medsize            A      1
# 4      Four-Door Car      Medsize          NaN      1
# ...              ...          ...          ...    ...
# 10905     Luxury Car      Medsize            A      1
# 10906  Four-Door Car      Medsize            A      1
# 10907     Luxury SUV      Medsize          NaN      2
# 10908            SUV      Medsize            A      2
# 10909            SUV      Medsize          NaN      1
#
# [10910 rows x 26 columns]

# %%
# checking for NaNs in the dataset

data.isna().sum()
# Out:
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# vehicle_type                     5482
# dtype: int64

# %%
# creating a separate dataframe that only keeps the duplicate rows from data 
# - this gives a result of 3292 duplicate rows, quite a lot in my opinion

duplicates = data[data.duplicated('customer',keep=False)==True]
duplicates
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 4      QA50777      Oregon              9025.067525       No   Premium
# 5      HO81102         NaN              4745.181764      NaN     Basic
# 11     GE63585         NaN              2420.711888      NaN     Basic
# 15     CW49887  California              4626.801093      Yes     Basic
# ...        ...         ...                      ...      ...       ...
# 10890  VQ78876      Oregon              4660.399573       No     Basic
# 10894  EX63393         NaN              6314.492009      NaN  Extended
# 10899  WU60905  California              8610.667489       No     Basic
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#                   education effective_to_date employmentstatus gender  income  \
# 0                   College           2/18/11         Employed      M   48029
# 4                  Bachelor           1/17/11    Medical Leave      F   23675
# 5      High School or Below           2/14/11         Employed      M   50549
# 11                 Bachelor            2/7/11         Employed      M   31710
# 15                   Master           1/16/11         Employed      F   79487
# ...                     ...               ...              ...    ...     ...
# 10890              Bachelor            2/3/11         Employed      F   89834
# 10894                Master           2/27/11         Employed      F   66947
# 10899  High School or Below            2/6/11       Unemployed      F       0
# 10905              Bachelor           1/19/11       Unemployed      F       0
# 10909              Bachelor            1/8/11       Unemployed      M       0
#
#       location_code marital_status  monthly_premium_auto  \
# 0          Suburban        Married                    61
# 4          Suburban        Married                   117
# 5          Suburban       Divorced                    61
# 11            Urban       Divorced                    62
# 15         Suburban       Divorced                   114
# ...             ...            ...                   ...
# 10890         Rural        Married                   116
# 10894      Suburban        Married                    78
# 10899      Suburban        Married                   111
# 10905      Suburban        Married                   253
# 10909      Suburban         Single                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 4                          NaN                             31
# 5                          2.0                             73
# 11                         5.0                             29
# 15                        20.0                             87
# ...                        ...                            ...
# 10890                     24.0                             11
# 10894                     13.0                             12
# 10899                     27.0                             36
# 10905                      NaN                             40
# 10909                     31.0                              1
#
#        number_of_open_complaints  number_of_policies     policy_type  \
# 0                            0.0                   9  Corporate Auto
# 4                            NaN                   7   Personal Auto
# 5                            0.0                   7   Personal Auto
# 11                           0.0                   1  Corporate Auto
# 15                           0.0                   1    Special Auto
# ...                          ...                 ...             ...
# 10890                        0.0                   1  Corporate Auto
# 10894                        0.0                   6   Personal Auto
# 10899                        0.0                   9  Corporate Auto
# 10905                        NaN                   7   Personal Auto
# 10909                        0.0                   3   Personal Auto
#
#              policy renew_offer_type sales_channel  total_claim_amount  \
# 0      Corporate L3           Offer3         Agent          292.800000
# 4       Personal L2           Offer1        Branch          707.925645
# 5       Personal L3           Offer1         Agent          292.800000
# 11     Corporate L3           Offer1   Call Center          199.551735
# 15       Special L1           Offer2        Branch          547.200000
# ...             ...              ...           ...                 ...
# 10890  Corporate L3           Offer1        Branch           43.155950
# 10894   Personal L1           Offer3         Agent          374.400000
# 10899  Corporate L1           Offer3           Web          532.800000
# 10905   Personal L1           Offer3           Web         1214.400000
# 10909   Personal L1           Offer4           Web         1021.719397
#
#        vehicle_class vehicle_size vehicle_type
# 0      Four-Door Car      Medsize          NaN
# 4      Four-Door Car      Medsize          NaN
# 5      Four-Door Car      Medsize            A
# 11      Two-Door Car      Medsize          NaN
# 15               SUV      Medsize          NaN
# ...              ...          ...          ...
# 10890            NaN          NaN          NaN
# 10894  Four-Door Car        Small          NaN
# 10899            SUV      Medsize            A
# 10905     Luxury Car      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [3292 rows x 25 columns]

# %% [markdown]
# **I used the below to examine some of the duplicate rows with the unique identifier 'customer' In doing so, I realized that these rows contain NaNs, which are often given a value in their duplicate rows. So to keep the integrity of the dataset, I thought it be best to merge duplicates and have python keep the relevant infomation in place of NaNs wherever possible**

# %%
duplicates[duplicates['customer']=='ID89933']
# Out:
#      customer   state  customer_lifetime_value response  coverage education  \
# 691   ID89933  Oregon              7255.577594       No  Extended    Doctor
# 950   ID89933  Oregon              7255.577594       No  Extended    Doctor
# 3389  ID89933     NaN              7255.577594      NaN  Extended    Doctor
# 4581  ID89933  Oregon              7255.577594       No  Extended    Doctor
# 4996  ID89933  Oregon              7255.577594       No  Extended    Doctor
# 6091  ID89933  Oregon              7255.577594       No  Extended    Doctor
# 6743  ID89933     NaN              7255.577594      NaN  Extended    Doctor
#
#      effective_to_date employmentstatus gender  income location_code  \
# 691             1/9/11         Employed      F   39786         Urban
# 950             1/9/11         Employed      F   39786         Urban
# 3389            1/9/11         Employed      F   39786         Urban
# 4581            1/9/11         Employed      F   39786         Urban
# 4996            1/9/11         Employed      F   39786         Urban
# 6091            1/9/11         Employed      F   39786         Urban
# 6743            1/9/11         Employed      F   39786         Urban
#
#      marital_status  monthly_premium_auto  months_since_last_claim  \
# 691         Married                    91                      NaN
# 950         Married                    91                      2.0
# 3389        Married                    91                      NaN
# 4581        Married                    91                      NaN
# 4996        Married                    91                      2.0
# 6091        Married                    91                      2.0
# 6743        Married                    91                      NaN
#
#       months_since_policy_inception  number_of_open_complaints  \
# 691                              91                        NaN
# 950                              91                        1.0
# 3389                             91                        NaN
# 4581                             91                        NaN
# 4996                             91                        1.0
# 6091                             91                        1.0
# 6743                             91                        NaN
#
#       number_of_policies    policy_type       policy renew_offer_type  \
# 691                    9  Personal Auto  Personal L2           Offer1
# 950                    9  Personal Auto  Personal L2           Offer1
# 3389                   9  Personal Auto  Personal L2           Offer1
# 4581                   9  Personal Auto  Personal L2           Offer1
# 4996                   9  Personal Auto  Personal L2           Offer1
# 6091                   9  Personal Auto  Personal L2           Offer1
# 6743                   9  Personal Auto  Personal L2           Offer1
#
#      sales_channel  total_claim_amount  vehicle_class vehicle_size  \
# 691            Web          365.835977            NaN          NaN
# 950            Web          365.835977            NaN          NaN
# 3389           Web          365.835977            NaN          NaN
# 4581           Web          365.835977            NaN          NaN
# 4996           Web          365.835977  Four-Door Car      Medsize
# 6091           Web          365.835977            NaN          NaN
# 6743           Web          365.835977            NaN          NaN
#
#      vehicle_type
# 691           NaN
# 950             A
# 3389          NaN
# 4581          NaN
# 4996            A
# 6091            A
# 6743          NaN

# %% [markdown]
# **After quite some research and trial and error on how to merge duplicate cells while preserving all valid data in place of NaNs, I came across the formula below, which instantly worked and seemingly merged all duplicates reliably!!!**

# %%
# the below cuts down 3292 duplicate rows to 1516 with intact data!

duplicates = duplicates.replace('',np.nan, regex=True)
duplicates1 = duplicates.groupby('customer',as_index=False,sort=False).last()
duplicates1
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     DK49336     Arizona              4809.216960       No     Basic
# 1     QA50777      Oregon              9025.067525       No   Premium
# 2     HO81102  Washington              4745.181764       No     Basic
# 3     GE63585  California              2420.711888       No     Basic
# 4     CW49887  California              4626.801093      Yes     Basic
# ...       ...         ...                      ...      ...       ...
# 1511  JE21522  California              9587.332340       No  Extended
# 1512  RI24911     Arizona              7507.455372      Yes     Basic
# 1513  ZP86347  California              5500.577411       No  Extended
# 1514  KF50730  California              5235.573528       No  Extended
# 1515  WX19595     Arizona             14429.892840       No     Basic
#
#                  education effective_to_date employmentstatus gender  income  \
# 0                  College           2/18/11         Employed      M   48029
# 1                 Bachelor           1/17/11    Medical Leave      F   23675
# 2     High School or Below           2/14/11         Employed      M   50549
# 3                 Bachelor            2/7/11         Employed      M   31710
# 4                   Master           1/16/11         Employed      F   79487
# ...                    ...               ...              ...    ...     ...
# 1511              Bachelor           2/26/11         Employed      M   39266
# 1512               College            2/6/11         Employed      M   60920
# 1513               College           2/12/11         Employed      F   44019
# 1514              Bachelor           2/21/11         Employed      F   71794
# 1515  High School or Below            1/1/11       Unemployed      M       0
#
#      location_code marital_status  monthly_premium_auto  \
# 0         Suburban        Married                    61
# 1         Suburban        Married                   117
# 2         Suburban       Divorced                    61
# 3            Urban       Divorced                    62
# 4         Suburban       Divorced                   114
# ...            ...            ...                   ...
# 1511      Suburban        Married                    80
# 1512         Urban         Single                    64
# 1513         Rural        Married                   138
# 1514         Urban        Married                   131
# 1515      Suburban        Married                   198
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                         7.0                             52
# 1                         4.0                             31
# 2                         2.0                             73
# 3                         5.0                             29
# 4                        20.0                             87
# ...                       ...                            ...
# 1511                     33.0                             31
# 1512                     10.0                             61
# 1513                     20.0                             60
# 1514                     19.0                             48
# 1515                      4.0                             31
#
#       number_of_open_complaints  number_of_policies     policy_type  \
# 0                           0.0                   9  Corporate Auto
# 1                           0.0                   7   Personal Auto
# 2                           0.0                   7   Personal Auto
# 3                           0.0                   1  Corporate Auto
# 4                           0.0                   1    Special Auto
# ...                         ...                 ...             ...
# 1511                        0.0                   2   Personal Auto
# 1512                        0.0                   2   Personal Auto
# 1513                        0.0                   1   Personal Auto
# 1514                        0.0                   1   Personal Auto
# 1515                        0.0                   9   Personal Auto
#
#             policy renew_offer_type sales_channel  total_claim_amount  \
# 0     Corporate L3           Offer3         Agent          292.800000
# 1      Personal L2           Offer1        Branch          707.925645
# 2      Personal L3           Offer1         Agent          292.800000
# 3     Corporate L3           Offer1   Call Center          199.551735
# 4       Special L1           Offer2        Branch          547.200000
# ...            ...              ...           ...                 ...
# 1511   Personal L2           Offer4        Branch          384.000000
# 1512   Personal L3           Offer2         Agent          231.201886
# 1513   Personal L3           Offer3         Agent          165.478147
# 1514   Personal L3           Offer2           Web          457.471225
# 1515   Personal L2           Offer4         Agent          962.159318
#
#       vehicle_class vehicle_size vehicle_type
# 0     Four-Door Car      Medsize            A
# 1     Four-Door Car      Medsize         None
# 2     Four-Door Car      Medsize            A
# 3      Two-Door Car      Medsize            A
# 4               SUV      Medsize         None
# ...             ...          ...          ...
# 1511  Four-Door Car      Medsize            A
# 1512   Two-Door Car      Medsize            A
# 1513            SUV      Medsize            A
# 1514            SUV      Medsize            A
# 1515     Luxury Car        Small            A
#
# [1516 rows x 25 columns]

# %%
# checking the result on a sample customer id

duplicates1[duplicates1['customer']=='ID89933']
# Out:
#     customer   state  customer_lifetime_value response  coverage education  \
# 200  ID89933  Oregon              7255.577594       No  Extended    Doctor
#
#     effective_to_date employmentstatus gender  income location_code  \
# 200            1/9/11         Employed      F   39786         Urban
#
#     marital_status  monthly_premium_auto  months_since_last_claim  \
# 200        Married                    91                      2.0
#
#      months_since_policy_inception  number_of_open_complaints  \
# 200                             91                        1.0
#
#      number_of_policies    policy_type       policy renew_offer_type  \
# 200                   9  Personal Auto  Personal L2           Offer1
#
#     sales_channel  total_claim_amount  vehicle_class vehicle_size vehicle_type
# 200           Web          365.835977  Four-Door Car      Medsize            A

# %%
# checking for NaNs in the cleaned dataset - just 337 NaNs remaining in vehicle_type! With these last cells I 
# decided to fill them with an 'unknown' value

duplicates1.isna().sum()
# Out:
# customer                           0
# state                              0
# customer_lifetime_value            0
# response                           0
# coverage                           0
# education                          0
# effective_to_date                  0
# employmentstatus                   0
# gender                             0
# income                             0
# location_code                      0
# marital_status                     0
# monthly_premium_auto               0
# months_since_last_claim            0
# months_since_policy_inception      0
# number_of_open_complaints          0
# number_of_policies                 0
# policy_type                        0
# policy                             0
# renew_offer_type                   0
# sales_channel                      0
# total_claim_amount                 0
# vehicle_class                      0
# vehicle_size                       0
# vehicle_type                     337
# dtype: int64

# %%
# to fill remaining NaNs with unknown

duplicates1 = duplicates1.fillna('unknown')

duplicates1.isna().sum()
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# dtype: int64

# %% [markdown]
# ## Based on this, I proceeded to incorporate the merger code into my function at the top
#
# ### Some notes:
# **While the duplicate merger seems to have worked to my expectation, I have no way of verifying whether in fact all these duplicates really merged super reliably.**

# %% [markdown]
# #
# #

# %% [markdown]
# # Lab | Customer Analysis Round 3
#
# For this lab, we still keep using the marketing_customer_analysis.csv file. You can find the file in the files_for_lab folder.
#
# ### Get the data
#
# - Use the same jupyter file from the last lab, Customer Analysis Round 3
#
# ### EDA (Exploratory Data Analysis) - Complete the following tasks to explore the data:
#
# - Show DataFrame info.
# - Describe DataFrame.
# - Show a plot of the total number of responses.
# - Show a plot of the response rate by the sales channel.
# - Show a plot of the response rate by the total claim amount.
# - Show a plot of the response rate by income.

# %%
data
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employmentstatus gender  income  \
# 0       College           2/18/11         Employed      M   48029
# 1       College           1/18/11       Unemployed      F       0
# 2      Bachelor           2/10/11         Employed      M   22139
# 3       College           1/11/11         Employed      M   49078
# 4      Bachelor           1/17/11    Medical Leave      F   23675
# ...         ...               ...              ...    ...     ...
# 10905  Bachelor           1/19/11       Unemployed      F       0
# 10906   College            1/6/11         Employed      F   61146
# 10907  Bachelor            2/6/11         Employed      F   39837
# 10908   College           2/13/11         Employed      F   64195
# 10909  Bachelor            1/8/11       Unemployed      M       0
#
#       location_code marital_status  monthly_premium_auto  \
# 0          Suburban        Married                    61
# 1          Suburban         Single                    64
# 2          Suburban         Single                   100
# 3          Suburban         Single                    97
# 4          Suburban        Married                   117
# ...             ...            ...                   ...
# 10905      Suburban        Married                   253
# 10906         Urban        Married                    65
# 10907         Rural        Married                   201
# 10908         Urban       Divorced                   158
# 10909      Suburban         Single                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# 2                         34.0                             31
# 3                         10.0                              3
# 4                          NaN                             31
# ...                        ...                            ...
# 10905                      NaN                             40
# 10906                      7.0                             68
# 10907                     11.0                             63
# 10908                      0.0                             27
# 10909                     31.0                              1
#
#        number_of_open_complaints  number_of_policies     policy_type  \
# 0                            0.0                   9  Corporate Auto
# 1                            0.0                   1   Personal Auto
# 2                            0.0                   2   Personal Auto
# 3                            0.0                   2  Corporate Auto
# 4                            NaN                   7   Personal Auto
# ...                          ...                 ...             ...
# 10905                        NaN                   7   Personal Auto
# 10906                        0.0                   6   Personal Auto
# 10907                        0.0                   2  Corporate Auto
# 10908                        4.0                   6   Personal Auto
# 10909                        0.0                   3   Personal Auto
#
#              policy renew_offer_type sales_channel  total_claim_amount  \
# 0      Corporate L3           Offer3         Agent          292.800000
# 1       Personal L3           Offer4   Call Center          744.924331
# 2       Personal L3           Offer3   Call Center          480.000000
# 3      Corporate L3           Offer2        Branch          484.013411
# 4       Personal L2           Offer1        Branch          707.925645
# ...             ...              ...           ...                 ...
# 10905   Personal L1           Offer3           Web         1214.400000
# 10906   Personal L3           Offer2        Branch          273.018929
# 10907  Corporate L3           Offer1           Web          381.306996
# 10908   Personal L1           Offer1        Branch          618.288849
# 10909   Personal L1           Offer4           Web         1021.719397
#
#        vehicle_class vehicle_size vehicle_type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 25 columns]

# %%
# not sure if you mean the function below by show dataframe info?

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10279 non-null  object
#  2   customer_lifetime_value        10910 non-null  float64
#  3   response                       10279 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective_to_date              10910 non-null  object
#  7   employmentstatus               10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location_code                  10910 non-null  object
#  11  marital_status                 10910 non-null  object
#  12  monthly_premium_auto           10910 non-null  int64
#  13  months_since_last_claim        10277 non-null  float64
#  14  months_since_policy_inception  10910 non-null  int64
#  15  number_of_open_complaints      10277 non-null  float64
#  16  number_of_policies             10910 non-null  int64
#  17  policy_type                    10910 non-null  object
#  18  policy                         10910 non-null  object
#  19  renew_offer_type               10910 non-null  object
#  20  sales_channel                  10910 non-null  object
#  21  total_claim_amount             10910 non-null  float64
#  22  vehicle_class                  10288 non-null  object
#  23  vehicle_size                   10288 non-null  object
#  24  vehicle_type                   5428 non-null   object
# dtypes: float64(4), int64(4), object(17)
# memory usage: 2.1+ MB

# %%
data.describe().T
# Out:
#                                  count          mean           std  \
# customer_lifetime_value        10910.0   8018.241094   6885.081434
# income                         10910.0  37536.284785  30359.195670
# monthly_premium_auto           10910.0     93.196059     34.442532
# months_since_last_claim        10277.0     15.149071     10.080349
# months_since_policy_inception  10910.0     48.091934     27.940675
# number_of_open_complaints      10277.0      0.384256      0.912457
# number_of_policies             10910.0      2.979193      2.399359
# total_claim_amount             10910.0    434.888330    292.180556
#
#                                        min          25%           50%  \
# customer_lifetime_value        1898.007675  4014.453113   5771.147235
# income                            0.000000     0.000000  33813.500000
# monthly_premium_auto             61.000000    68.000000     83.000000
# months_since_last_claim           0.000000     6.000000     14.000000
# months_since_policy_inception     0.000000    24.000000     48.000000
# number_of_open_complaints         0.000000     0.000000      0.000000
# number_of_policies                1.000000     1.000000      2.000000
# total_claim_amount                0.099007   271.082527    382.564630
#
#                                         75%           max
# customer_lifetime_value         8992.779137  83325.381190
# income                         62250.750000  99981.000000
# monthly_premium_auto             109.000000    298.000000
# months_since_last_claim           23.000000     35.000000
# months_since_policy_inception     71.000000     99.000000
# number_of_open_complaints          0.000000      5.000000
# number_of_policies                 4.000000      9.000000
# total_claim_amount               547.200000   2893.239678
